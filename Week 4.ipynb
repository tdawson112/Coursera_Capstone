# %% [markdown]
# Applied Data Science Capstone

# %% [markdown]
# ## (1) Introduction/Business Problem

# %% [markdown]
# Minneapolis is located in Minnesota and represents one half of the famous "twin-cities". In 2018, the population was measured at 425,403. Saturated with 18 Fortune 500 companie and many lakes, parks and trails, Minneapolis is a great balance between business and outdoor activity.
#
# Additionally, Minneapolis is becoming more and more known for its food scene. Becuase of this, we will dive into the data of the city in hopes of finding a preferred location for a restaurant to open up within Minneapolis.

# %% [markdown]
# ## 2) Data

# %% [markdown]
# #### Source:
# Foursquare API - used to get the various venues in different neighborhoods
# https://opendata.minneapolismn.gov/datasets/minneapolis-neighborhoods?geometry=-93.426%2C44.950%2C-93.097%2C44.992 - used to get the neighborhood boundries of Minneapolis.

# %% [markdown]
# #### Intial data Wrangling and Cleaning
#
# The cleansed data will then be used alongside Foursquare data. Foursquare location data will be leveraged to explore districts around New york city, identifying the high traffic areas where consumers go for shopping, dining and entertainment - the areas where the fashion brand are most interested in opening new stores.
#
# #### Visualization:
# Analysis and plotting visualizations to better understand the data
